# %%
import pandas as pd

dengue = pd.read_csv('dengue-dataset.csv', sep=',', encoding='utf-8')

# %%
dengue.head()
# Out:
#          data  casos-confirmados  chuva  temperatura-media  \
# 0  1998-01-01                237  179.2               25.7
# 1  1998-02-01                331  226.3               25.1
# 2  1998-03-01                562  149.1               24.8
# 3  1998-04-01                187   46.4               22.7
# 4  1998-05-01                 32   88.3               19.2
#
#    temperatura-mininima  temperatura-maxima
# 0                  20.2                28.1
# 1                  20.0                28.0
# 2                  22.4                27.2
# 3                  18.1                26.0
# 4                  15.7                22.9

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def time_stamp(begin, end, column):
    dates = []
    values = []
    
    f_begin = False
    
    for index, row in dengue.iterrows():
        if (row["data"] == begin):
            f_begin = True
        
        if (f_begin):
            dates.append(row["data"])
            values.append(row[column])
        
        if (row["data"] == end):
            f_begin = False
            
    
    return (dates, values)

# %%
ts = time_stamp('1998-01-01', '1998-12-01', 'chuva')

# %%
ts[0]
# Out:
# ['1998-01-01',
#  '1998-02-01',
#  '1998-03-01',
#  '1998-04-01',
#  '1998-05-01',
#  '1998-06-01',
#  '1998-07-01',
#  '1998-08-01',
#  '1998-09-01',
#  '1998-10-01',
#  '1998-11-01',
#  '1998-12-01']

# %%
#plot simples

fig, ax = plt.subplots()
plt.plot_date(ts[0], ts[1])
ax.xaxis.set_tick_params(rotation=60, labelsize=10)

plt.show()

# %%
import matplotlib.dates as mdates

data = pd.read_csv('dengue-dataset.csv', usecols=['data','chuva'], parse_dates=['data'])
data.set_index('data',inplace=True)

fig, ax = plt.subplots(figsize=(24,7))
data.plot(ax=ax)


ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# %%
data = pd.read_csv('dengue-dataset.csv', usecols=['data','chuva'], parse_dates=['data'])
data.set_index('data',inplace=True)

fig, ax = plt.subplots(figsize=(10,7))
data[1:12].plot(ax=ax)

ax.xaxis.set_major_locator(mdates.WeekdayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# %% [markdown]
# Mais detalhes: https://scentellegher.github.io/programming/2017/05/24/pandas-bar-plot-with-formatted-dates.html
